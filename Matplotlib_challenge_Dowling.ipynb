# %% [markdown]
# I don't think we talked much about the map charts (Geospatial data), and I'm going to take a bit of creative freedom on this question and instead of data relevant to my career trajectory (let's be real, I'm closer to the sunset of my trajectory than I am the start of it), I'm going to use data relevant to my retirement years (which I hope are still several years away). I'd like create a map of "where most female surfers over age 50 live" and data I would want to see on this visual would include; population, number of female surf clubs and / or groups, numbers of campgrounds, nearest national parks, average air temps, average water temps, best months for intermediate waves, and of course average cost of living. Although I think it's going to limit the data quite a bit, I'm going to narrow my focus to include only North America since if I do move, I still want to stay close to my kids.

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
ced = pd.read_csv('cces_example_data.csv')

# %%
ced = pd.read_csv('cces_example_data.csv')
ced.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
type(ced['age'])
# Out:
# pandas.core.series.Series

# %%
type(ced['age'])
#trying to get some info on frequencies of responses here
# Out:
# pandas.core.series.Series

# %%
fig1, ax1 = plt.subplots()
plt.show()

# %%
fig2, axs2 = plt.subplots(2,2)

# %%
fig2, axs2 = plt.subplots(2,2)
axs2[0, 0].set_title("Age Histogram")
#found on cheat sheet :)


plt.show()

# %%
fig2, axs2 = plt.subplots(2,2)
axs2[0, 0].set_title("Age Histogram")
axs2[0, 1].set_title("Political Identity")


plt.show()

# %%
fig2, axs2 = plt.subplots(2,2)
axs2[0, 0].set_title("Age Histogram")
axs2[0, 1].set_title("Political Identity")

plt.show()

# %%
ced[''] = ced[''].astype('')
#pulled this from line 14 of the demo notebook but still don't know how to get frequencies of responses

# %% [markdown]
# -In a new code cell, create and show a figure that includes one axes that displays a bar plot of the frequencies of responses in the `Evaluation` variable. For this step you must apply pandas methods of summarizing this data
#
# -In a new code cell, create and show a figure that includes one axes that displays a scatter plot of the `ConMediaUse` and `ImmiPhobia` variables
#
# -In a Markdown cell, describe methods of improving the `ConMediaUse` and `ImmiPhobia` scatterplot
# In this answer, be sure to discuss specific elements from the week's required materials and provide citations with section/page numbers for relevant course materials
