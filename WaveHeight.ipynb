# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
wave = pd.read_csv('Climatological_WaveHeight_Period_WavePower_HSOFS.csv')
wave.head() 
#this is a wave height data set from sciencebase.gov 
#how to filter and zoom this pt on the coast go to week 3 or 4 get items 
#decide on a list of cities find lon/lat of each
# Out:
#          lon        Lat         H         T         P
# 0 -91.196021  30.424800  0.012050  0.065328  0.004654
# 1 -91.193699  30.423873  0.004659  0.100013  0.001065
# 2 -91.198342  30.425727  0.012622  0.061718  0.004824
# 3 -91.200664  30.426654  0.012302  0.062331  0.004628
# 4 -91.202985  30.427581  0.009789  0.073051  0.003434

# %%
wave.columns #according to chatgpt, lon=east to west geographic coordinate,
#lat=north to south geographic coordinate, H=height, T=time between wave crests, P=power
# Out:
# Index(['lon', 'Lat', 'H', 'T', 'P'], dtype='object')

# %%
wave.shape #yikes
# Out:
# (1813443, 5)

# %%
np = pd.read_csv('National_Parks.csv')
np.head #should i find a way to find national parks near beaches
# Out:
# <bound method NDFrame.head of      OBJECTID UNIT_CODE                                          GIS_Notes  \
# 0           1      APIS  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 1           2      EFMO  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 2           3      GUIS  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 3           4      HAFE  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 4           5      HEHO  Lands - http://landsnet.nps.gov/tractsnet/docu...
# ..        ...       ...                                                ...
# 432       433      PIPE  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 433       434      FOPU  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 434       435      STEA  Lands - https://landsnet.nps.gov/tractsnet/doc...
# 435       436      KEMO  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 436       437      CEBE  Lands - http://landsnet.nps.gov/tractsnet/docu...
#
# ...
