# %%
my_var = 35

# %%
my_var + 12
# Out:
# 47

# %%
def give_name():
    my_var + 24
    print("Kristin")

# give_name()

# %%
def return_name():
    return "Kristin"

name = return_name()

# %%
name
# Out:
# 'Kristin'

# %%
for i in [1, 2, 3,]:
    print (i)
# Out:
# 1
# 2
# 3

# %%
[print(i) for i in [1,2, 3]]
# Out:
# 1
# 2
# 3
# [None, None, None]

# %% [markdown]
# ![alt](IMG_6897.jpeg)

# %%
import pandas as pd

# %%
data_dict = {'a': [1,2,3], 'b':[4,5,6]}
data_list = [{'a':1, 'b':4}, {'a': 2, 'b': 5}, {'a':3, 'b':6}]

dat = pd.DataFrame(data_dict)
dat
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dat2 = pd.DataFrame (data_list)
dat2
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dat.head(1)
# Out:
#    a  b
# 0  1  4

# %%
dat.tail(1)
# Out:
#    a  b
# 2  3  6

# %%
dat['a']
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %%
dat.loc[0]
# Out:
# a    1
# b    4
# Name: 0, dtype: int64

# %%
dat.iloc[0]
# Out:
# a    1
# b    4
# Name: 0, dtype: int64

# %%
dat.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
len(dat.index)
# Out:
# 3

# %%
len(dat.columns)
# Out:
# 2

# %%
dat[['a', 'b']]
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dat[dat['a'] >2]
# Out:
#    a  b
# 2  3  6

# %%
dat[dat['a'] >2]['a']
# Out:
# 2    3
# Name: a, dtype: int64

# %%
dat.write_csv()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tg/tyhvgh7x3_zfjmpm7y0nqq8c0000gp/T/ipykernel_14631/2015343518.py in ?()
# ----> 1 dat.write_scv()
#
# /opt/anaconda3/envs/OkData/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'write_scv'

# %%
dat.write_csv()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dat.write_csv()
#
# NameError: name 'dat' is not defined

# %% [markdown]
# What does the "write/render/evaluate" loop provide for creators of interactive data visualizations?
#     According to Murray, it provides for rapid experimentation and is critical to the iterative process.
# Why are dynamic, interactive data visualizations useful when communicating data?
#     They allow users to drill down on data they find interesting and explore it for themselves.
# Do you agree with Murray's claim that open-source tools that avoid proprietary software are best for publishing data visualization? In a few sentences, explain why you do or do not agree.
#     I neither agree nor disagree with this statement because I don't feel well enough informed yet at this point. I have used Tableu and PowerBI but only a little bit so I don't know if these are neccessarily "better" or "worse" than open-source tools. I do believe that if proprietary software tools are good enough for the visualizations that are needed in businesses that can afford the expense of the software license, then it probably makes sense. It's likely easier to onboard new employees and support them in terms of training. It's possible that I have this backwards too, that the open-source tools are easier more broadly known. I'm not sure but I hope to learn more about it.
