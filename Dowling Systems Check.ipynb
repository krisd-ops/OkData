# %% [markdown]
# # Systems Check
# ### Kristin Dowling
# ##### EMAT 62119

# %%
my_name = "Kristin"
my_name
# Out:
# 'Kristin'

# %%
def return_name():
    return my_name

new_name=return_name()

# %%
def give_name():
    print(my_name)

give_name()
# Out:
# Kristin

# %% [markdown]
# # What do I hope to gain from this course?
# ## Kristin Dowling
# 1. Practical Python skills (I don't plan to do a lot of coding but it would be *nice* to understand and be able to do so if needed)
# 2. The ability to think about data differently and find better ways to tell the story behind it
# 3. Stretch my **brain** muscle :)
#
# This is my cat **Rocket**. I know it looks like he's ready for a hike, but he **hates** the outdoors.
#
# ![alt](IMG_6897.jpeg)
